# %% [markdown]
# #Store Sales Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('/content/Store_Sales _Data.csv',encoding='unicode_escape')
data.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
data.shape
# Out:
# (11251, 15)

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
data.sample(5)
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 1496   1003412  Apsingekar  P00350942      F     26-35   28               1
# 166    1004377     Sibella  P00298942      M     26-35   26               0
# 10769  1000530   Chayanika  P00331842      F     26-35   35               0
# 1770   1002565        Kean  P00154642      F     36-45   45               0
# 4781   1000746      Uudhav  P00078142      M     18-25   20               1
#
#              State      Zone Occupation    Product_Category  Orders   Amount  \
# 1496         Delhi   Central    Textile    Footwear & Shoes       1  16240.0
# 166      Karnataka  Southern     Retail    Footwear & Shoes       3  20676.0
# 10769       Kerala  Southern   Chemical  Clothing & Apparel       1   1969.0
# 1770   Maharashtra   Western   Aviation                Food       1  15780.0
# 4781       Gujarat   Western    Banking  Clothing & Apparel       3   8857.0
#
#        Status  unnamed1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
data.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
data.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
data['Amount'].isnull().sum()
# Out:
# np.int64(12)

# %%
Amt_avg=data['Amount'].mean()
Amt_avg
# Out:
# np.float64(9453.610857727557)

# %%
data['Amount'].fillna(Amt_avg,inplace=True)
# Out:
# /tmp/ipykernel_2131/519691012.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Amount'].fillna(Amt_avg,inplace=True)

# %%
data.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                  0
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
data.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11251 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
data['Amount'] = data['Amount'].astype('int')
data['Amount'].dtypes
# Out:
# dtype('int64')

# %%
data.rename(columns={'unnamed2':'Product_Category'},inplace=True)

# %%
ax = sns.countplot(x='Gender',data=data)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# set style
sns.set_style("whitegrid")
#Create figure
plt.figure(figsize=(8,5))
#plot
ax = sns.countplot(x='Gender',data=data,palette='pastel',edgecolor='black')

ax.set_title("Gender Distribution", fontsize=14,fontweight='bold')
ax.set_xlabel("Gender",fontsize=12)
ax.set_ylabel("Count",fontsize=12)
for bars in ax.containers:
    ax.bar_label(bars)
sns.despine()
# Out:
# /tmp/ipykernel_2131/3108727139.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Gender',data=data,palette='pastel',edgecolor='black')

# %%
'''add datalabel in bars
for p in ax.patches:
  ax.annotate(f'{int(p.get-height())}',
              (p.get_x() + p.get_width()/2., p.get_height()),
              ha='center',va='bottom',
              size=10
              )'''
# Out:
# "add datalabel in bars\nfor p in ax.patches:\n  ax.annotate(f'{int(p.get-height())}',\n              (p.get_x() + p.get_width()/2., p.get_height()),\n              ha='center',va='bottom',\n              size=10\n              )"

# %%
#plotting a bar cahrt for gender vs total amount

sales_gen = data.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Gender',y='Amount',data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are female and even the purcasing power of females are greater than man*

# %%
#age
bar_color= ['pink','blue']
ax = sns.countplot(data=data, x='Age Group', hue = 'Gender',palette={'F':'purple','M':'blue'})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_age = data.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Age Group',y='Amount',data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *from above graph we can see that most of the buyers are of age group between 26-35 yrs female*

# %%
# total number of order from top 10 states
sales_state = data.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='State',y='Orders',data=sales_state,palette='rocket')
# Out:
# /tmp/ipykernel_2131/1944157023.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='State',y='Orders',data=sales_state,palette='rocket')
# <Axes: xlabel='State', ylabel='Orders'>

# %%
#total amount/sales from top 10 states
sales_state = data.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='State',y='Amount',data=sales_state,palette='colorblind')
# Out:
# /tmp/ipykernel_2131/226813350.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='State',y='Amount',data=sales_state,palette='colorblind')
# <Axes: xlabel='State', ylabel='Amount'>

# %%
ax=sns.countplot(data=data,x='Marital_Status')
for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_state = data.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x='Marital_Status',y='Amount',data=sales_state,hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From above graphs we caxn see that most of the buyers are unmarried (women) and they have high purchasing power*

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.countplot(data=data,x='Occupation')

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_state = data.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Occupation',y='Amount',data=sales_state)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From Above Graphs we can see the most buyers are working in IT , Healthcare and Aviation sector*

# %% [markdown]
# #Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.countplot(data=data,x='Product_Category')
plt.xticks(rotation=45)
plt.grid(1)

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_state=data.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Product_Category',y='Amount',data=sales_state)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *from above graphs we can see that most of the sold products are food , clothes and electronics*

# %%
sales_state = data.groupby(['Product_ID'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Product_ID',y='Orders',data=sales_state)
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# #top 10 most sold products

# %%
# top 10 most sold products
fig1, ax1 = plt.subplots(figsize=(12,7))
data.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# # Conclusion :

# %% [markdown]
# ## *married women age group 25-35 yrs from UP, Maharastra and Karnataka Working in IT , Healthcare and Aviation are most likely to buy products from Food , Clothing and Electronics Category*
